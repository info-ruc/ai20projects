# %%
# load the library using the import keyword
# OpenCV must be properly installed for this to work. If not, then the module will not load with an
# error message.

import cv2
import sys

# Gets the name of the image file (filename) from sys.argv
imagePath = "face2.jpg"
cascPath = "haarcascade_frontalface_default.xml"

# This creates the cascade classifcation from file 

faceCascade = cv2.CascadeClassifier(cascPath)
# The image is read and converted to grayscale
image = cv2.imread(imagePath)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# The face or faces in an image are detected
# This section requires the most adjustments to get accuracy on face being detected.


faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(1,1),
    flags = cv2.CASCADE_SCALE_IMAGE
)
print("Detected {0} faces!".format(len(faces)))

# This draws a green rectangle around the faces detected


for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
cv2.imshow("Faces Detected", image)
cv2.waitKey(0)
# The image is read and converted to grayscale
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-f43a7c7796fd> in <module>
#      15 # The image is read and converted to grayscale
#      16 image = cv2.imread(imagePath)
# ---> 17 gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#      18 # The face or faces in an image are detected
#      19 # This section requires the most adjustments to get accuracy on face being detected.
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
import cv2
import sys
import time
def facedetect(imagePath,i):
#######################################################
#检测人脸，同时与标准中心对比，计算出deltax deltay deltaz
#center_x center_y expected center, 常数值 可根据需要调整
#Ideal_area 期望面积 常数值
#######################################################
    center_x=347
    center_y=400
    Ideal_area=102.01
    cascPath = "haarcascade_frontalface_default.xml" 

    faceCascade = cv2.CascadeClassifier(cascPath)
    
    image = cv2.imread(imagePath)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    time_start=time.time()

    faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(1,1),
    flags = cv2.CASCADE_SCALE_IMAGE
    )
    count=0
    if (faces !=()):
        for (x,y,w,h) in faces:
            #框出人脸范围
         #   cv2.imshow("Faces Detected", image)
          #  cv2.waitKey(0)
            cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
            time_end=time.time()
          #  cv2.imshow("Faces Detected", image)
          #  cv2.waitKey(0)
            
         #   roi_gray = gray[y:y+h, x:x+w]
         #   roi_color = img[y:y+h, x:x+w]
         #计算图片中人脸的中心点，bounding_center_coordinates_x,y
            bounding_centre_coordinates_x = int((x+x+w)/2)
            bounding_centre_coordinates_y = int((y+y+h)/2)
            cv2.circle(image,(bounding_centre_coordinates_x, bounding_centre_coordinates_y), 5, (0,255,0), -1)
           # cv2.imshow("Faces Detected", image)
           # cv2.waitKey(0)
            cv2.imwrite('outcascade'+str(i)+'.jpg', image)
            Area_z=w*h
            print("x",bounding_centre_coordinates_x)
            print("y",bounding_centre_coordinates_y)
            print("s",Area_z)
            #将图中的中心点与期望中心点作差，算出变化量
            print((-center_x+bounding_centre_coordinates_x), (center_y-bounding_centre_coordinates_y), (-1*Ideal_area+Area_z)/100)
            x_axis = -center_x + bounding_centre_coordinates_x
            y_axis = center_y - bounding_centre_coordinates_y
            z_axis= int((-102010+Area_z)/10000)
            print("delta x y z",x_axis,y_axis,z_axis)
            
            print('time cost',time_end-time_start,'s')
        
            
    else: 
        print("no face!")

# %%
count=0
for i in range(150):
    
    facedetect("./testvedio_000/testvedio_"+str(i).zfill(3)+".jpg",i)
    print('this is image',i)
# Out:
# no face!
# this is image 0
# no face!
# this is image 1
# no face!
# this is image 2
# no face!
# this is image 3
# C:\Users\10725\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
# x 854
# y 209
# s 2601
# 507 191 24.9899
# delta x y z 507 191 -9
# time cost 0.32114076614379883 s
# this is image 4
# no face!
# this is image 5
# x 855
# y 210
# s 2704
# 508 190 26.019899999999996
# delta x y z 508 190 -9
# time cost 0.3291192054748535 s
# this is image 6
# x 855
# y 209
# s 2601
# 508 191 24.9899
# delta x y z 508 191 -9
# time cost 0.3510453701019287 s
# x 114
# y 292
# s 3249
# -233 108 31.4699
# delta x y z -233 108 -9
# time cost 0.37398433685302734 s
# this is image 7
# x 855
# y 209
# s 2916
# 508 191 28.139899999999997
# delta x y z 508 191 -9
# time cost 0.36103320121765137 s
# this is image 8
# x 853
# y 209
# s 2601
# 506 191 24.9899
# delta x y z 506 191 -9
# time cost 0.38496923446655273 s
# x 116
# y 292
# s 3364
# -231 108 32.6199
# delta x y z -231 108 -9
# time cost 0.40691208839416504 s
# this is image 9
# x 855
# y 209
# s 2601
# 508 191 24.9899
# delta x y z 508 191 -9
# time cost 0.37101054191589355 s
# x 115
# y 292
# s 3249
# -232 108 31.4699
# delta x y z -232 108 -9
# time cost 0.39294886589050293 s
# this is image 10
# x 855
# y 209
# s 2809
# 508 191 27.069899999999997
# delta x y z 508 191 -9
# time cost 0.37998175621032715 s
# x 115
# y 292
# s 3136
# -232 108 30.339899999999997
# delta x y z -232 108 -9
# time cost 0.39893198013305664 s
# this is image 11
# x 854
# y 209
# s 2601
# 507 191 24.9899
# delta x y z 507 191 -9
# time cost 0.34607458114624023 s
# x 116
# y 292
# s 3364
# -231 108 32.6199
# delta x y z -231 108 -9
# time cost 0.362032413482666 s
# this is image 12
# x 855
# y 209
# s 2500
# 508 191 23.979899999999997
# delta x y z 508 191 -9
# time cost 0.3420860767364502 s
# x 115
# y 291
# s 3481
# -232 109 33.789899999999996
# delta x y z -232 109 -9
# time cost 0.35704612731933594 s
# this is image 13
# x 805
# y 349
# s 4356
# 458 51 42.539899999999996
# delta x y z 458 51 -9
# time cost 0.356048583984375 s
# this is image 14
# x 807
# y 345
# s 4489
# 460 55 43.8699
# delta x y z 460 55 -9
# time cost 0.32712507247924805 s
# this is image 15
# x 810
# y 336
# s 4356
# 463 64 42.539899999999996
# delta x y z 463 64 -9
# time cost 0.27326345443725586 s
# this is image 16
# x 807
# y 331
# s 4225
# 460 69 41.2299
# delta x y z 460 69 -9
# time cost 0.30219268798828125 s
# x 877
# y 534
# s 4096
# 530 -134 39.939899999999994
# delta x y z 530 -134 -9
# time cost 0.31914806365966797 s
# this is image 17
# x 821
# y 335
# s 4489
# 474 65 43.8699
# delta x y z 474 65 -9
# time cost 0.2682802677154541 s
# x 1146
# y 283
# s 3600
# 799 117 34.9799
# delta x y z 799 117 -9
# time cost 0.28623485565185547 s
# x 910
# y 548
# s 5625
# 563 -148 55.2299
# delta x y z 563 -148 -9
# time cost 0.30019640922546387 s
# this is image 18
# x 837
# y 332
# s 4624
# 490 68 45.219899999999996
# delta x y z 490 68 -9
# time cost 0.2602651119232178 s
# x 289
# y 479
# s 4225
# -58 -79 41.2299
# delta x y z -58 -79 -9
# time cost 0.2772195339202881 s
# x 919
# y 548
# s 5329
# 572 -148 52.2699
# delta x y z 572 -148 -9
# time cost 0.29517364501953125 s
# x 1144
# y 283
# s 3600
# 797 117 34.9799
# delta x y z 797 117 -9
# time cost 0.3111300468444824 s
# this is image 19
# x 853
# y 328
# s 4489
# 506 72 43.8699
# delta x y z 506 72 -9
# time cost 0.27323246002197266 s
# x 923
# y 545
# s 3721
# 576 -145 36.189899999999994
# delta x y z 576 -145 -9
# time cost 0.2911851406097412 s
# x 288
# y 479
# s 3844
# -59 -79 37.4199
# delta x y z -59 -79 -9
# time cost 0.3071424961090088 s
# this is image 20
# x 855
# y 331
# s 4489
# 508 69 43.8699
# delta x y z 508 69 -9
# time cost 0.26573634147644043 s
# x 288
# y 479
# s 3969
# -59 -79 38.6699
# delta x y z -59 -79 -9
# time cost 0.2806978225708008 s
# this is image 21
# x 824
# y 353
# s 4900
# 477 47 47.9799
# delta x y z 477 47 -9
# time cost 0.32811880111694336 s
# this is image 22
# x 802
# y 371
# s 5476
# 455 29 53.7399
# delta x y z 455 29 -9
# time cost 0.30019688606262207 s
# this is image 23
# x 758
# y 384
# s 5476
# 411 16 53.7399
# delta x y z 411 16 -9
# time cost 0.3181486129760742 s
# this is image 24
# x 743
# y 360
# s 6084
# 396 40 59.8199
# delta x y z 396 40 -9
# time cost 0.2862358093261719 s
# this is image 25
# no face!
# this is image 26
# no face!
# this is image 27
# no face!
# this is image 28
# x 555
# y 79
# s 2601
# 208 321 24.9899
# delta x y z 208 321 -9
# time cost 0.3071770668029785 s
# this is image 29
# no face!
# this is image 30
# no face!
# this is image 31
# no face!
# this is image 32
# no face!
# this is image 33
# no face!
# this is image 34
# no face!
# this is image 35
# no face!
# this is image 36
# no face!
# this is image 37
# no face!
# this is image 38
# x 156
# y 80
# s 4624
# -191 320 45.219899999999996
# delta x y z -191 320 -9
# time cost 0.12765741348266602 s
# this is image 39
# x 698
# y 431
# s 26244
# 351 -31 261.41990000000004
# delta x y z 351 -31 -7
# time cost 0.1296529769897461 s
# this is image 40
# x 492
# y 325
# s 7396
# 145 75 72.9399
# delta x y z 145 75 -9
# time cost 0.10571599006652832 s
# this is image 41
# no face!
# this is image 42
# no face!
# this is image 43
# no face!
# this is image 44
# no face!
# this is image 45
# no face!
# this is image 46
# no face!
# this is image 47
# no face!
# this is image 48
# x 340
# y 111
# s 3721
# -7 289 36.189899999999994
# delta x y z -7 289 -9
# time cost 0.10770893096923828 s
# this is image 49
# no face!
# this is image 50
# x 154
# y 80
# s 4489
# -193 320 43.8699
# delta x y z -193 320 -9
# time cost 0.12865400314331055 s
# this is image 51
# x 702
# y 427
# s 26896
# 355 -27 267.9399
# delta x y z 355 -27 -7
# time cost 0.12865447998046875 s
# this is image 52
# no face!
# this is image 53
# no face!
# this is image 54
# no face!
# this is image 55
# x 154
# y 80
# s 4489
# -193 320 43.8699
# delta x y z -193 320 -9
# time cost 0.12266945838928223 s
# this is image 56
# no face!
# this is image 57
# no face!
# this is image 58
# no face!
# this is image 59
# no face!
# this is image 60
# no face!
# this is image 61
# no face!
# this is image 62
# no face!
# this is image 63
# x 608
# y 206
# s 4624
# 261 194 45.219899999999996
# delta x y z 261 194 -9
# time cost 0.13763022422790527 s
# this is image 64
# x 609
# y 202
# s 4761
# 262 198 46.5899
# delta x y z 262 198 -9
# time cost 0.1406235694885254 s
# x 912
# y 253
# s 5929
# 565 147 58.2699
# delta x y z 565 147 -9
# time cost 0.15857672691345215 s
# this is image 65
# x 541
# y 241
# s 46656
# 194 159 465.5399
# delta x y z 194 159 -5
# time cost 0.14760375022888184 s
# this is image 66
# x 539
# y 264
# s 61504
# 192 136 614.0199
# delta x y z 192 136 -4
# time cost 0.1296532154083252 s
# this is image 67
# no face!
# this is image 68
# x 661
# y 257
# s 841
# 314 143 7.3899
# delta x y z 314 143 -10
# time cost 0.1685492992401123 s
# this is image 69
# x 660
# y 258
# s 900
# 313 142 7.9799
# delta x y z 313 142 -10
# time cost 0.16356277465820312 s
# this is image 70
# x 654
# y 262
# s 961
# 307 138 8.5899
# delta x y z 307 138 -10
# time cost 0.18350934982299805 s
# this is image 71
# x 653
# y 265
# s 1024
# 306 135 9.2199
# delta x y z 306 135 -10
# time cost 0.1605689525604248 s
# this is image 72
# x 652
# y 269
# s 1024
# 305 131 9.2199
# delta x y z 305 131 -10
# time cost 0.21242880821228027 s
# this is image 73
# x 651
# y 271
# s 1089
# 304 129 9.8699
# delta x y z 304 129 -10
# time cost 0.18051719665527344 s
# this is image 74
# no face!
# this is image 75
# no face!
# this is image 76
# no face!
# this is image 77
# x 629
# y 255
# s 1089
# 282 145 9.8699
# delta x y z 282 145 -10
# time cost 0.15558242797851562 s
# this is image 78
# x 625
# y 254
# s 1024
# 278 146 9.2199
# delta x y z 278 146 -10
# time cost 0.1605701446533203 s
# x 120
# y 420
# s 4761
# -227 -20 46.5899
# delta x y z -227 -20 -9
# time cost 0.1795191764831543 s
# this is image 79
# x 608
# y 212
# s 39601
# 261 188 394.9899
# delta x y z 261 188 -6
# time cost 0.11469292640686035 s
# this is image 80
# x 639
# y 216
# s 39204
# 292 184 391.0199
# delta x y z 292 184 -6
# time cost 0.11568856239318848 s
# this is image 81
# x 669
# y 218
# s 40804
# 322 182 407.0199
# delta x y z 322 182 -6
# time cost 0.1246640682220459 s
# this is image 82
# x 706
# y 229
# s 40401
# 359 171 402.9899
# delta x y z 359 171 -6
# time cost 0.12366724014282227 s
# this is image 83
# x 741
# y 247
# s 37249
# 394 153 371.4699
# delta x y z 394 153 -6
# time cost 0.16655468940734863 s
# this is image 84
# x 756
# y 264
# s 32041
# 409 136 319.3899
# delta x y z 409 136 -6
# time cost 0.1715412139892578 s
# x 686
# y 408
# s 14884
# 339 -8 147.8199
# delta x y z 339 -8 -8
# time cost 0.19750618934631348 s
# this is image 85
# x 767
# y 270
# s 22500
# 420 130 223.97990000000001
# delta x y z 420 130 -7
# time cost 0.1625654697418213 s
# this is image 86
# no face!
# this is image 87
# no face!
# this is image 88
# no face!
# this is image 89
# no face!
# this is image 90
# no face!
# this is image 91
# no face!
# this is image 92
# no face!
# this is image 93
# x 763
# y 203
# s 25600
# 416 197 254.97990000000001
# delta x y z 416 197 -7
# time cost 0.11369585990905762 s
# this is image 94
# x 793
# y 195
# s 33124
# 446 205 330.2199
# delta x y z 446 205 -6
# time cost 0.13164687156677246 s
# this is image 95
# x 830
# y 249
# s 33856
# 483 151 337.5399
# delta x y z 483 151 -6
# time cost 0.1186833381652832 s
# this is image 96
# x 862
# y 350
# s 35721
# 515 50 356.18989999999997
# delta x y z 515 50 -6
# time cost 0.11269879341125488 s
# this is image 97
# x 680
# y 392
# s 11236
# 333 8 111.3399
# delta x y z 333 8 -9
# time cost 0.10471773147583008 s
# x 891
# y 450
# s 37636
# 544 -50 375.3399
# delta x y z 544 -50 -6
# time cost 0.12067580223083496 s
# this is image 98
# no face!
# this is image 99
# no face!
# this is image 100
# no face!
# this is image 101
# no face!
# this is image 102
# no face!
# this is image 103
# no face!
# this is image 104
# no face!
# this is image 105
# no face!
# this is image 106
# x 875
# y 476
# s 40401
# 528 -76 402.9899
# delta x y z 528 -76 -6
# time cost 0.16754984855651855 s
# this is image 107
# x 868
# y 460
# s 36100
# 521 -60 359.9799
# delta x y z 521 -60 -6
# time cost 0.15259313583374023 s
# x 734
# y 286
# s 2916
# 387 114 28.139899999999997
# delta x y z 387 114 -9
# time cost 0.17553138732910156 s
# this is image 108
# x 851
# y 403
# s 33856
# 504 -3 337.5399
# delta x y z 504 -3 -6
# time cost 0.12765812873840332 s
# this is image 109
# x 829
# y 360
# s 34225
# 482 40 341.2299
# delta x y z 482 40 -6
# time cost 0.16156697273254395 s
# this is image 110
# x 602
# y 514
# s 9025
# 255 -114 89.2299
# delta x y z 255 -114 -9
# time cost 0.1326448917388916 s
# x 821
# y 348
# s 33124
# 474 52 330.2199
# delta x y z 474 52 -6
# time cost 0.14860296249389648 s
# this is image 111
# x 799
# y 319
# s 30625
# 452 81 305.22990000000004
# delta x y z 452 81 -7
# time cost 0.20345687866210938 s
# this is image 112
# x 786
# y 314
# s 33856
# 439 86 337.5399
# delta x y z 439 86 -6
# time cost 0.15957403182983398 s
# this is image 113
# x 776
# y 311
# s 36864
# 429 89 367.6199
# delta x y z 429 89 -6
# time cost 0.15708494186401367 s
# this is image 114
# x 765
# y 309
# s 35344
# 418 91 352.4199
# delta x y z 418 91 -6
# time cost 0.15658020973205566 s
# this is image 115
# x 752
# y 310
# s 36864
# 405 90 367.6199
# delta x y z 405 90 -6
# time cost 0.17852044105529785 s
# this is image 116
# x 745
# y 307
# s 38416
# 398 93 383.13989999999995
# delta x y z 398 93 -6
# time cost 0.1745312213897705 s
# this is image 117
# x 731
# y 302
# s 37636
# 384 98 375.3399
# delta x y z 384 98 -6
# time cost 0.17553138732910156 s
# this is image 118
# x 714
# y 291
# s 38416
# 367 109 383.13989999999995
# delta x y z 367 109 -6
# time cost 0.2044534683227539 s
# this is image 119
# x 702
# y 283
# s 40804
# 355 117 407.0199
# delta x y z 355 117 -6
# time cost 0.15757369995117188 s
# this is image 120
# x 678
# y 262
# s 39204
# 331 138 391.0199
# delta x y z 331 138 -6
# time cost 0.20046186447143555 s
# this is image 121
# x 668
# y 253
# s 39204
# 321 147 391.0199
# delta x y z 321 147 -6
# time cost 0.19547414779663086 s
# this is image 122
# x 657
# y 244
# s 40000
# 310 156 398.9799
# delta x y z 310 156 -6
# time cost 0.1825120449066162 s
# this is image 123
# x 649
# y 240
# s 38025
# 302 160 379.2299
# delta x y z 302 160 -6
# time cost 0.1845083236694336 s
# this is image 124
# x 643
# y 240
# s 37636
# 296 160 375.3399
# delta x y z 296 160 -6
# time cost 0.18849587440490723 s
# this is image 125
# x 638
# y 241
# s 40804
# 291 159 407.0199
# delta x y z 291 159 -6
# time cost 0.17253780364990234 s
# this is image 126
# x 639
# y 244
# s 42849
# 292 156 427.4699
# delta x y z 292 156 -5
# time cost 0.22539758682250977 s
# this is image 127
# x 638
# y 244
# s 43681
# 291 156 435.7899
# delta x y z 291 156 -5
# time cost 0.17054295539855957 s
# this is image 128
# no face!
# this is image 129
# no face!
# this is image 130
# no face!
# this is image 131
# no face!
# this is image 132
# no face!
# this is image 133
# x 156
# y 80
# s 4489
# -191 320 43.8699
# delta x y z -191 320 -9
# time cost 0.1077113151550293 s
# this is image 134
# x 156
# y 79
# s 4225
# -191 321 41.2299
# delta x y z -191 321 -9
# time cost 0.11868119239807129 s
# this is image 135
# no face!
# this is image 136
# x 673
# y 251
# s 119716
# 326 149 1196.1399000000001
# delta x y z 326 149 1
# time cost 0.11967873573303223 s
# this is image 137
# no face!
# this is image 138
# no face!
# this is image 139
# x 717
# y 322
# s 38025
# 370 78 379.2299
# delta x y z 370 78 -6
# time cost 0.11369609832763672 s
# this is image 140
# x 712
# y 320
# s 39601
# 365 80 394.9899
# delta x y z 365 80 -6
# time cost 0.12566113471984863 s
# this is image 141
# no face!
# this is image 142
# no face!
# this is image 143
# x 724
# y 313
# s 26896
# 377 87 267.9399
# delta x y z 377 87 -7
# time cost 0.11369538307189941 s
# this is image 144
# no face!
# this is image 145
# x 726
# y 324
# s 31684
# 379 76 315.8199
# delta x y z 379 76 -7
# time cost 0.11269760131835938 s
# this is image 146
# no face!
# this is image 147
# no face!
# this is image 148
# x 729
# y 323
# s 25600
# 382 77 254.97990000000001
# delta x y z 382 77 -7
# time cost 0.11967992782592773 s
# this is image 149

# %%
def command(x_axis,y_axis,z_axis):
############################################
#输入delatax delatay deltaz 输出相应命令
#是未完成代码，需要填充合适的命令格式
#############################################
      if( -50 < x_axis < 50):
            if(-38 < y_axis < 38):
                if(-7 < z_axis < 18):
                   # self.tello.send_rc_control(0,0,0,0) 不动   
                else:
                    if(z_axis > 18):
                       # self.for_back_velocity = -30
                       # self.tello.send_rc_control(0,self.for_back_velocity,0,0) 
                       #z较大，要向前
                    elif(z_axis < -7):
                        #self.for_back_velocity = 30
                       # self.tello.send_rc_control(0,self.for_back_velocity,0,0)
                       #z较小的情况
            else:
                if(y_axis>38):
                  #  self.up_down_velocity = 30
                   # self.tello.send_rc_control(0,0, self.up_down_velocity,0)
                    #y较大的情况，前后调整               
                elif(y_axis<-38):
                    #
                   # self.up_down_velocity = -30
                   # self.tello.send_rc_control(0,0, self.up_down_velocity,0)       
        else:
            if(x_axis > 50):
                #self.yaw_velocity = -20
                #self.tello.send_rc_control(0,0,0,self.yaw_velocity)
                                
            elif(x_axis < -50):
                #self.yaw_velocity = 20
               # self.tello.send_rc_control(0,0,0,self.yaw_velocity)
            #X较大或较小，调整左右

# %%
def run():
    while(True):
        #####################################
        #截一张此刻图保存在某一文件夹/xx/yy下
        #####################################
        
        x_axis,y_axis,z_axis=facedetect("/xx/yy")
        
        com=command(x_axis,y_axis,z_axis)
        
        ########################################
        #命令执行
        ########################################
        
         time.sleep(30)

# %%
import cv2

#图片视频转换
fps = 10    
size = (960,544)
#可以用(*'DVIX')或(*'X264'),如果都不行先装ffmepg: sudo apt-get install ffmepg
fourcc = cv2.VideoWriter_fourcc(*'X264')
videoWriter = cv2.VideoWriter('outvi.avi',fourcc,fps,size)#最后一个是保存图片的尺寸

#for(i=1;i<471;++i)
for i in range(1,140):
    frame = cv2.imread("./testvedio_000/testvedio_"+str(i).zfill(3)+".jpg")
    videoWriter.write(frame)
videoWriter.release()
